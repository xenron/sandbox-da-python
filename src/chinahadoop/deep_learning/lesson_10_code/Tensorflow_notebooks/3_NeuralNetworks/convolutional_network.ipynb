# %% [markdown]
# ## Tensorflow卷积神经网络案例

# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# 超参数
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# 神经网络参数设定
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf 计算图输入
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 20305.441406, Training Accuracy= 0.22656
# Iter 2560, Minibatch Loss= 10258.636719, Training Accuracy= 0.42969
# Iter 3840, Minibatch Loss= 7388.729980, Training Accuracy= 0.57812
# Iter 5120, Minibatch Loss= 2766.893799, Training Accuracy= 0.82812
# Iter 6400, Minibatch Loss= 2485.437500, Training Accuracy= 0.82812
# Iter 7680, Minibatch Loss= 6464.452148, Training Accuracy= 0.71875
# Iter 8960, Minibatch Loss= 3212.274414, Training Accuracy= 0.78125
# Iter 10240, Minibatch Loss= 2645.508789, Training Accuracy= 0.84375
# Iter 11520, Minibatch Loss= 1722.774902, Training Accuracy= 0.89062
# Iter 12800, Minibatch Loss= 2842.004150, Training Accuracy= 0.79688
# Iter 14080, Minibatch Loss= 765.778809, Training Accuracy= 0.90625
# Iter 15360, Minibatch Loss= 1357.441772, Training Accuracy= 0.92188
# Iter 16640, Minibatch Loss= 2174.123047, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 1345.969727, Training Accuracy= 0.90625
# Iter 19200, Minibatch Loss= 1113.999023, Training Accuracy= 0.91406
# Iter 20480, Minibatch Loss= 116.929741, Training Accuracy= 0.97656
# Iter 21760, Minibatch Loss= 2301.699951, Training Accuracy= 0.84375
# Iter 23040, Minibatch Loss= 837.342468, Training Accuracy= 0.92969
# Iter 24320, Minibatch Loss= 1317.337280, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 1176.409180, Training Accuracy= 0.89062
# Iter 26880, Minibatch Loss= 1063.679077, Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 955.816162, Training Accuracy= 0.94531
# Iter 29440, Minibatch Loss= 1508.362549, Training Accuracy= 0.89844
# Iter 30720, Minibatch Loss= 733.741760, Training Accuracy= 0.92188
# Iter 32000, Minibatch Loss= 766.480835, Training Accuracy= 0.92969
# Iter 33280, Minibatch Loss= 1163.353271, Training Accuracy= 0.89844
# Iter 34560, Minibatch Loss= 313.414551, Training Accuracy= 0.95312
# Iter 35840, Minibatch Loss= 152.863678, Training Accuracy= 0.97656
# Iter 37120, Minibatch Loss= 1061.007324, Training Accuracy= 0.95312
# Iter 38400, Minibatch Loss= 131.688843, Training Accuracy= 0.98438
# Iter 39680, Minibatch Loss= 235.094711, Training Accuracy= 0.98438
# Iter 40960, Minibatch Loss= 1338.591064, Training Accuracy= 0.91406
# Iter 42240, Minibatch Loss= 533.119385, Training Accuracy= 0.92969
# Iter 43520, Minibatch Loss= 424.309021, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 334.007507, Training Accuracy= 0.96094
# Iter 46080, Minibatch Loss= 93.976913, Training Accuracy= 0.97656
# Iter 47360, Minibatch Loss= 591.424255, Training Accuracy= 0.95312
# Iter 48640, Minibatch Loss= 838.480103, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 477.531372, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 391.012451, Training Accuracy= 0.95312
# Iter 52480, Minibatch Loss= 314.000305, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 141.759613, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 191.396576, Training Accuracy= 0.99219
# Iter 56320, Minibatch Loss= 161.314545, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 284.038086, Training Accuracy= 0.95312
# Iter 58880, Minibatch Loss= 598.773254, Training Accuracy= 0.92969
# Iter 60160, Minibatch Loss= 358.639496, Training Accuracy= 0.98438
# Iter 61440, Minibatch Loss= 277.376678, Training Accuracy= 0.96875
# Iter 62720, Minibatch Loss= 710.999756, Training Accuracy= 0.93750
# Iter 64000, Minibatch Loss= 534.375732, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 489.164856, Training Accuracy= 0.94531
# Iter 66560, Minibatch Loss= 925.967651, Training Accuracy= 0.93750
# Iter 67840, Minibatch Loss= 119.128021, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 355.091675, Training Accuracy= 0.95312
# Iter 70400, Minibatch Loss= 285.658875, Training Accuracy= 0.97656
# Iter 71680, Minibatch Loss= 241.383911, Training Accuracy= 0.96875
# Iter 72960, Minibatch Loss= 637.175293, Training Accuracy= 0.93750
# Iter 74240, Minibatch Loss= 584.359741, Training Accuracy= 0.92188
# Iter 75520, Minibatch Loss= 105.446030, Training Accuracy= 0.97656
# Iter 76800, Minibatch Loss= 19.907974, Training Accuracy= 0.99219
# Iter 78080, Minibatch Loss= 535.134277, Training Accuracy= 0.96094
# Iter 79360, Minibatch Loss= 385.750671, Training Accuracy= 0.94531
# Iter 80640, Minibatch Loss= 17.866257, Training Accuracy= 0.99219
# Iter 81920, Minibatch Loss= 304.624878, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 171.277695, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 247.355377, Training Accuracy= 0.97656
# Iter 85760, Minibatch Loss= 127.122932, Training Accuracy= 0.98438
# Iter 87040, Minibatch Loss= 186.221893, Training Accuracy= 0.97656
# Iter 88320, Minibatch Loss= 596.843140, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 305.708740, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 273.291595, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 507.631836, Training Accuracy= 0.92188
# Iter 93440, Minibatch Loss= 46.616516, Training Accuracy= 0.99219
# Iter 94720, Minibatch Loss= 91.281586, Training Accuracy= 0.98438
# Iter 96000, Minibatch Loss= 357.093689, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 455.581696, Training Accuracy= 0.92969
# Iter 98560, Minibatch Loss= 268.134521, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 278.695618, Training Accuracy= 0.97656
# Iter 101120, Minibatch Loss= 407.327271, Training Accuracy= 0.96094
# Iter 102400, Minibatch Loss= 267.821899, Training Accuracy= 0.96875
# Iter 103680, Minibatch Loss= 291.449768, Training Accuracy= 0.96875
# Iter 104960, Minibatch Loss= 852.559631, Training Accuracy= 0.94531
# Iter 106240, Minibatch Loss= 353.603210, Training Accuracy= 0.95312
# Iter 107520, Minibatch Loss= 54.693981, Training Accuracy= 0.98438
# Iter 108800, Minibatch Loss= 129.203644, Training Accuracy= 0.97656
# Iter 110080, Minibatch Loss= 16.820190, Training Accuracy= 0.99219
# Iter 111360, Minibatch Loss= 27.574875, Training Accuracy= 0.99219
# Iter 112640, Minibatch Loss= 135.604736, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 126.023529, Training Accuracy= 0.96875
# Iter 115200, Minibatch Loss= 160.208221, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 319.208771, Training Accuracy= 0.95312
# Iter 117760, Minibatch Loss= 251.977661, Training Accuracy= 0.96875
# Iter 119040, Minibatch Loss= 65.015007, Training Accuracy= 0.96875
# Iter 120320, Minibatch Loss= 95.806625, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 327.165070, Training Accuracy= 0.97656
# Iter 122880, Minibatch Loss= 285.971893, Training Accuracy= 0.96094
# Iter 124160, Minibatch Loss= 316.214172, Training Accuracy= 0.96875
# Iter 125440, Minibatch Loss= 110.387306, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 266.178833, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 24.701813, Training Accuracy= 0.99219
# Iter 129280, Minibatch Loss= 229.858826, Training Accuracy= 0.95312
# Iter 130560, Minibatch Loss= 360.300354, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 161.670044, Training Accuracy= 0.94531
# Iter 133120, Minibatch Loss= 95.742706, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 33.794563, Training Accuracy= 0.98438
# Iter 135680, Minibatch Loss= 244.538635, Training Accuracy= 0.96875
# Iter 136960, Minibatch Loss= 87.435440, Training Accuracy= 0.97656
# Iter 138240, Minibatch Loss= 10.570168, Training Accuracy= 0.98438
# Iter 139520, Minibatch Loss= 149.348358, Training Accuracy= 0.96875
# Iter 140800, Minibatch Loss= 136.337921, Training Accuracy= 0.96875
# Iter 142080, Minibatch Loss= 267.241089, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 65.084122, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 180.975815, Training Accuracy= 0.98438
# Iter 145920, Minibatch Loss= 187.193146, Training Accuracy= 0.95312
# Iter 147200, Minibatch Loss= 174.250336, Training Accuracy= 0.96875
# Iter 148480, Minibatch Loss= 318.798645, Training Accuracy= 0.95312
# Iter 149760, Minibatch Loss= 95.043167, Training Accuracy= 0.96875
# Iter 151040, Minibatch Loss= 12.401497, Training Accuracy= 0.98438
# Iter 152320, Minibatch Loss= 460.338593, Training Accuracy= 0.93750
# Iter 153600, Minibatch Loss= 137.018707, Training Accuracy= 0.98438
# Iter 154880, Minibatch Loss= 13.638573, Training Accuracy= 0.99219
# Iter 156160, Minibatch Loss= 31.704628, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 98.899551, Training Accuracy= 0.98438
# Iter 158720, Minibatch Loss= 128.426559, Training Accuracy= 0.97656
# Iter 160000, Minibatch Loss= 284.743469, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 498.889954, Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 71.821785, Training Accuracy= 0.99219
# Iter 163840, Minibatch Loss= 97.194672, Training Accuracy= 0.97656
# Iter 165120, Minibatch Loss= 205.823212, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 76.652664, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 84.373795, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 82.110489, Training Accuracy= 0.99219
# Iter 170240, Minibatch Loss= 38.853638, Training Accuracy= 0.98438
# Iter 171520, Minibatch Loss= 117.567497, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 355.840698, Training Accuracy= 0.95312
# Iter 174080, Minibatch Loss= 167.058777, Training Accuracy= 0.97656
# Iter 175360, Minibatch Loss= 101.173134, Training Accuracy= 0.96875
# Iter 176640, Minibatch Loss= 105.398041, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 72.861847, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 79.591270, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 181760, Minibatch Loss= 147.914490, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 65.088829, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 76.404793, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 186880, Minibatch Loss= 52.821388, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 81.965378, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 190720, Minibatch Loss= 527.412048, Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 83.578094, Training Accuracy= 0.99219
# Iter 193280, Minibatch Loss= 276.417542, Training Accuracy= 0.96094
# Iter 194560, Minibatch Loss= 66.066673, Training Accuracy= 0.97656
# Iter 195840, Minibatch Loss= 169.254929, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 268.857056, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 105.516968, Training Accuracy= 0.98438
# Iter 199680, Minibatch Loss= 114.672546, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.976562
